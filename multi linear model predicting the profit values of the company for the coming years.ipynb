# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mat

# %%
pwd
# Out:
# 'C:\\Users\\HP'

# %%
cd E:\PYTHON FOR DA\Multiple_Linear_Regression
# Out:
# E:\PYTHON FOR DA\Multiple_Linear_Regression

# %%
pwd
# Out:
# 'E:\\PYTHON FOR DA\\Multiple_Linear_Regression'

# %%
df=pd.read_csv('50_Startups.csv')

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
X=df.iloc[:,0:4].values

# %%
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'Florida'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'Florida'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'Florida'],
#        [100671.96, 91790.61, 249744.55, 'California'],
#        [93863.75, 127320.38, 249839.44, 'Florida'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
Y=df.iloc[:,4:].values

# %%
Y
# Out:
# array([[192261.83],
#        [191792.06],
#        [191050.39],
#        [182901.99],
#        [166187.94],
#        [156991.12],
#        [156122.51],
#        [155752.6 ],
#        [152211.77],
#        [149759.96],
#        [146121.95],
#        [144259.4 ],
#        [141585.52],
#        [134307.35],
#        [132602.65],
#        [129917.04],
#        [126992.93],
#        [125370.37],
#        [124266.9 ],
#        [122776.86],
#        [118474.03],
#        [111313.02],
#        [110352.25],
#        [108733.99],
#        [108552.04],
#        [107404.34],
#        [105733.54],
#        [105008.31],
#        [103282.38],
#        [101004.64],
#        [ 99937.59],
#        [ 97483.56],
#        [ 97427.84],
#        [ 96778.92],
#        [ 96712.8 ],
#        [ 96479.51],
#        [ 90708.19],
#        [ 89949.14],
#        [ 81229.06],
#        [ 81005.76],
#        [ 78239.91],
#        [ 77798.83],
#        [ 71498.49],
#        [ 69758.98],
#        [ 65200.33],
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
l_x=LabelEncoder()
X[:,3]=l_x.fit_transform(X[:,3])

# %%
X
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 1.0000000e+00, 4.8000000e+01,
#         1.3689780e+05, 4.7178410e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.7000000e+01,
#         1.5137759e+05, 4.4389853e+05],
#        [1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 4.6000000e+01,
#         1.0114555e+05, 4.0793454e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.0000000e+00, 4.5000000e+01,
#         1.1867185e+05, 3.8319962e+05],
#        [1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 4.4000000e+01,
#         9.1391770e+04, 3.6616842e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.0000000e+00, 4.2000000e+01,
#         9.9814710e+04, 3.6286136e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.3000000e+01,
#         1.4719887e+05, 1.2771682e+05],
#        [1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 4.1000000e+01,
#         1.4553006e+05, 3.2387668e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.0000000e+00, 3.9000000e+01,
#         1.4871895e+05, 3.1161329e+05],
# ...

# %%
X=X[:,1:]

# %%
X
# Out:
# array([[0.0000000e+00, 1.0000000e+00, 4.8000000e+01, 1.3689780e+05,
#         4.7178410e+05],
#        [0.0000000e+00, 0.0000000e+00, 4.7000000e+01, 1.5137759e+05,
#         4.4389853e+05],
#        [1.0000000e+00, 0.0000000e+00, 4.6000000e+01, 1.0114555e+05,
#         4.0793454e+05],
#        [0.0000000e+00, 1.0000000e+00, 4.5000000e+01, 1.1867185e+05,
#         3.8319962e+05],
#        [1.0000000e+00, 0.0000000e+00, 4.4000000e+01, 9.1391770e+04,
#         3.6616842e+05],
#        [0.0000000e+00, 1.0000000e+00, 4.2000000e+01, 9.9814710e+04,
#         3.6286136e+05],
#        [0.0000000e+00, 0.0000000e+00, 4.3000000e+01, 1.4719887e+05,
#         1.2771682e+05],
#        [1.0000000e+00, 0.0000000e+00, 4.1000000e+01, 1.4553006e+05,
#         3.2387668e+05],
#        [0.0000000e+00, 1.0000000e+00, 3.9000000e+01, 1.4871895e+05,
#         3.1161329e+05],
#        [0.0000000e+00, 0.0000000e+00, 4.0000000e+01, 1.0867917e+05,
#         3.0498162e+05],
# ...

# %%
from sklearn.cross_validation import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
l=LinearRegression()
l.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Y_pred=l.predict(X_test)

# %%
Y_pred
# Out:
# array([[100815.65143643],
#        [141065.32323456],
#        [140351.4842569 ],
#        [ 69602.81317407],
#        [171849.80561966],
#        [115796.48839866],
#        [ 64138.93341569],
#        [ 88177.53284686],
#        [114766.47156368],
#        [165080.49074038]])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,Y_pred)
# Out:
# 0.9217139712234428

# %%
#applying backward elimination
import statsmodels.formula.api as sm
X=np.append(arr=np.ones((50,1)).astype(int),values=X,axis=1)

# %%
X_train
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 1.5000000e+01, 1.0305749e+05,
#         2.1463481e+05],
#        [0.0000000e+00, 1.0000000e+00, 1.3000000e+01, 8.5047440e+04,
#         2.0551764e+05],
#        [1.0000000e+00, 0.0000000e+00, 2.5000000e+01, 1.4413598e+05,
#         1.3405007e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.4000000e+01, 1.5769392e+05,
#         2.1079767e+05],
#        [1.0000000e+00, 0.0000000e+00, 3.1000000e+01, 1.1417579e+05,
#         2.9491957e+05],
#        [1.0000000e+00, 0.0000000e+00, 4.1000000e+01, 1.4553006e+05,
#         3.2387668e+05],
#        [1.0000000e+00, 0.0000000e+00, 3.8000000e+01, 1.5654742e+05,
#         2.5651292e+05],
#        [0.0000000e+00, 1.0000000e+00, 2.0000000e+00, 1.2415304e+05,
#         1.9039300e+03],
#        [0.0000000e+00, 1.0000000e+00, 1.0000000e+00, 5.1743150e+04,
#         0.0000000e+00],
#        [0.0000000e+00, 1.0000000e+00, 2.0000000e+01, 1.5303206e+05,
#         1.0713838e+05],
# ...

# %%
X_opt=X_train[:,[0,1,2,3,4]]

# %%
r_OLS=sm.OLS(endog=Y_train,exog=X_opt).fit()
r_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                     536.2
# Date:                Mon, 21 Jan 2019   Prob (F-statistic):           5.07e-32
# Time:                        19:25:06   Log-Likelihood:                -436.42
# No. Observations:                  40   AIC:                             882.8
# Df Residuals:                      35   BIC:                             891.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          -931.0072   5806.377     -0.160      0.874   -1.27e+04    1.09e+04
# ...

# %%
X_opt=X_train[:,[0,2,3,4]]
r_OLS=sm.OLS(endog=Y_train,exog=X_opt).fit()
r_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.986
# Method:                 Least Squares   F-statistic:                     680.7
# Date:                Mon, 21 Jan 2019   Prob (F-statistic):           2.26e-33
# Time:                        19:26:51   Log-Likelihood:                -436.67
# No. Observations:                  40   AIC:                             881.3
# Df Residuals:                      36   BIC:                             888.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1         -2470.4143   5283.819     -0.468      0.643   -1.32e+04    8245.668
# ...

# %%
X_opt=X_train[:,[2,3,4]]
r_OLS=sm.OLS(endog=Y_train,exog=X_opt).fit()
r_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.986
# Method:                 Least Squares   F-statistic:                     927.1
# Date:                Mon, 21 Jan 2019   Prob (F-statistic):           7.56e-35
# Time:                        19:26:54   Log-Likelihood:                -436.79
# No. Observations:                  40   AIC:                             879.6
# Df Residuals:                      37   BIC:                             884.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          2139.5403    229.847      9.309      0.000    1673.826    2605.255
# ...

# %%
X_opt
# Out:
# array([[1.5000000e+01, 1.0305749e+05, 2.1463481e+05],
#        [1.3000000e+01, 8.5047440e+04, 2.0551764e+05],
#        [2.5000000e+01, 1.4413598e+05, 1.3405007e+05],
#        [1.4000000e+01, 1.5769392e+05, 2.1079767e+05],
#        [3.1000000e+01, 1.1417579e+05, 2.9491957e+05],
#        [4.1000000e+01, 1.4553006e+05, 3.2387668e+05],
#        [3.8000000e+01, 1.5654742e+05, 2.5651292e+05],
#        [2.0000000e+00, 1.2415304e+05, 1.9039300e+03],
#        [1.0000000e+00, 5.1743150e+04, 0.0000000e+00],
#        [2.0000000e+01, 1.5303206e+05, 1.0713838e+05],
#        [3.7000000e+01, 1.2261684e+05, 2.6177623e+05],
#        [1.7000000e+01, 1.1564128e+05, 9.1131240e+04],
#        [1.8000000e+01, 1.2921961e+05, 4.6085250e+04],
#        [2.8000000e+01, 1.2159755e+05, 2.6434606e+05],
#        [7.0000000e+00, 9.6189630e+04, 1.4800111e+05],
#        [2.6000000e+01, 1.1386730e+05, 2.9866447e+05],
#        [4.0000000e+00, 1.2738230e+05, 3.5534170e+04],
# ...

# %%
l.fit(X_opt,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = l.predict(X_test[:,[2,3,4]])

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.9283649221698026

# %%
np.mean(abs(y_pred - Y_test))
# Out:
# 7657.168832576024
